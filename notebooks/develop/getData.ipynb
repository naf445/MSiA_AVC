# %%
import boto3
import pandas as pd
import io

# %%
s3 = boto3.resource("s3")
bucket = s3.Bucket("nw-nathanfranklin-423-s3")
bucket.download_file("booksummaries/booksummaries.txt", "../data/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-96-e18e8586b1cc> in <module>
#       1 s3 = boto3.resource("s3")
#       2 bucket = s3.Bucket("nw-nathanfranklin-423-s3")
# ----> 3 bucket.download_file("booksummaries/booksummaries.txt", "../data/")
#
# /anaconda3/envs/AVC/lib/python3.7/site-packages/boto3/s3/inject.py in bucket_download_file(self, Key, Filename, ExtraArgs, Callback, Config)
#     244     return self.meta.client.download_file(
#     245         Bucket=self.name, Key=Key, Filename=Filename,
# --> 246         ExtraArgs=ExtraArgs, Callback=Callback, Config=Config)
#     247
#     248
#
# /anaconda3/envs/AVC/lib/python3.7/site-packages/boto3/s3/inject.py in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     170         return transfer.download_file(
#     171             bucket=Bucket, key=Key, filename=Filename,
# ...

# %%
books.head
# Out:
# <bound method NDFrame.head of             620     /m/0hhy  \
# 0           843     /m/0k36
# 1           986     /m/0ldx
# 2          1756     /m/0sww
# 3          2080     /m/0wkt
# 4          2152     /m/0x5g
# 5          2890    /m/011zx
# 6          2950    /m/012dq
# 7          4081    /m/01b4w
# 8          4082    /m/01b56
# 9          4331    /m/01d3j
# 10         4332    /m/01d40
# 11         4376    /m/01dlg
# 12         4381    /m/01dnz
# 13         4382    /m/01dpg
# 14         4386    /m/01dqt
# 15         4449    /m/01f8p
# 16         4451    /m/01f9l
# 17         4452    /m/01fb1
# 18         4454    /m/01fby
# 19         6020    /m/01t5z
# 20         6628    /m/01y92
# 21         6629    /m/01y9j
# 22         6630    /m/01yb0
# 23         6921    /m/01_mr
# 24         7817    /m/025zx
# 25         7923    /m/026l0
# 26         8237    /m/0297f
# 27         8547    /m/02ct8
# 28         8567    /m/02cxx
# 29         8757    /m/02fck
# ...         ...         ...
# ...
